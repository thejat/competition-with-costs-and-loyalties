# %%
#Plots for the duopoly price discrimination model with loyalty and costs: Single stage Mult Loyalty LL case

# %load_ext autoreload
# %autoreload 2
from utils.imports import *
from utils.single_stage import *
from utils.utils import *

# %%
#keep cb fixed and ca is varied
flag_plot = True
flag_theory = True
dist = 'uniform'
cb = 0.4
la = 1
lb = 4
sa = 3
sb = 3
theta = 0.8
npts = 40 
ca_arr = np.linspace(cb,10,100) #ca >= cb, hardcode
maxpx=ca_arr.max()+5
df = ll_get_metric_arrs_vs_camcb(ca_arr,cb,la,lb,sa,sb,maxpx,npts,dist,theta,flag_theory=True)
ca_m_cb_arr = ca_arr - cb
# Out:
# ll_get_metric_arrs_vs_camcb start:  2021-09-27 16:41:27.982453
# i,ca,time:  0 0.4 2021-09-27 16:41:27.983453
# region not defined
# i,ca,time:  1 0.497 2021-09-27 16:41:27.985452
# region not defined
# i,ca,time:  2 0.594 2021-09-27 16:41:27.986456
# region not defined
# i,ca,time:  3 0.691 2021-09-27 16:41:27.987452
# region not defined
# i,ca,time:  4 0.788 2021-09-27 16:41:27.988451
# region not defined
# i,ca,time:  5 0.885 2021-09-27 16:41:27.990452
# region not defined
# i,ca,time:  6 0.982 2021-09-27 16:41:27.991454
# region not defined
# i,ca,time:  7 1.079 2021-09-27 16:41:27.992453
# region not defined
# i,ca,time:  8 1.176 2021-09-27 16:41:27.994454
# region not defined
# i,ca,time:  9 1.273 2021-09-27 16:41:27.995453
# region not defined
# i,ca,time:  10 1.37 2021-09-27 16:41:27.997452
# region not defined
# i,ca,time:  11 1.467 2021-09-27 16:41:27.998452
# i,ca,time:  12 1.564 2021-09-27 16:41:28.000456
# i,ca,time:  13 1.661 2021-09-27 16:41:28.001454
# ...

# %%
vert_line_locs1 = [sa-la,sa+2*la]
vert_line_locs1_labels = [r'$c_a - c_b = s_{\alpha}-l_{\alpha}$',r'$c_a-c_b=s_a+2l_{\alpha}$']
labels1=[r'$p_{A}^{\alpha}$',r'$p_{B}^{\alpha}$']
fname_prices_a = "./ll_single_stage_paa_pba.png" if flag_plot else None
plot_curves_vs_camcb(df['paa'],df['pba'],ca_m_cb_arr,'Prices',labels1,vert_line_locs1,vert_line_locs1_labels,fname_prices_a)

# %%
vert_line_locs2 = [lb-sb]
labels2=[r'$p_{B}^{\beta}$',r'$p_{A}^{\beta}$']
vert_line_locs2_labels = [r'$c_a - c_b = l_{\beta}-s_{\beta}$']
fname_prices_b = "./ll_single_stage_pbb_pab.png" if flag_plot else None
plot_curves_vs_camcb(df['pbb'],df['pab'],ca_m_cb_arr,'Prices',labels2,vert_line_locs2,vert_line_locs2_labels,fname_prices_b)

# %%
vert_line_locs3 = [lb-sb,sa-la,sa+2*la]
labels3=[r'Firm A',r'Firm B']
fname_market_share = "./ll_single_stage_market_share.png" if flag_plot else None
plot_curves_vs_camcb(df['marketshare_a'],df['marketshare_b'],ca_m_cb_arr,'Market Share',labels3,vert_line_locs3,None,fname_market_share)

# %%
vert_line_locs3 = [lb-sb,sa-la,sa+2*la]
labels3=[r'Firm A',r'Firm B']
fname_profits = "./ll_single_stage_profits.png" if flag_plot else None
plot_curves_vs_camcb(df['total_profit_a'],
                     df['total_profit_b'],ca_m_cb_arr,'Profit',labels3,vert_line_locs3,None,fname_profits)

# %%
vert_line_locs3 = [lb-sb,sa-la,sa+2*la]
labels3=[r'Firm A',r'Firm B']
fname_probabilities = "./ll_single_stage_probabilities.png" if flag_plot else None
plot_curves_vs_camcb(df['prob_purchase_a_from_a'],
                     df['prob_purchase_b_from_b'],ca_m_cb_arr,'Prob. of Purchase',labels3,vert_line_locs3,None,fname_probabilities)
